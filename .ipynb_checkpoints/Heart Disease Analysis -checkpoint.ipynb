# %% [markdown]
# ## Importing Libraries and Dataset

# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('heart.csv')
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# ###  Display top 5 rows in  the dataset

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
#   - age
#   - sex
#   - chest pain type (4 values)
#       * value 0: typical angina
#       * value 1: atypical angina
#       * value 2: non-anginal pain
#       * value 3: asymptomatic
#    - trestbps : resting blood pressure (in mm Hg on admission to the
#                 hospital)
#    - chol : serum cholestoral in mg/dl
#    - fbs : (fasting blood sugar > 120 mg/dl)(1 = true; 0 = false)
#    - restecg : resting electrocardiographic results
#       * value 0: normal
#       * value 1: having ST-T wave abnormally (T wave inversions and/or ST
#                   elevation or depression of > 0.05 mV)
#       * value 2: showing probable or definite left ventricular hypertrophy
#                   by Estes' criteria
#    - thalach : maximum heart rate achieved
#    - exang : exercise induced angina (1=yes;0=no)
#    - oldpeak = ST depression induced by exercise relative to rest
#    - Slope : the slope of the peak exercise ST segment
#       * value 1: upsloping
#       * value 2: flat
#       * value 3: downsloping
#    - ca : number of major vessels (0-3) colored by flourosopy
#    - thal : 3 = normal; 6=fixed detect; 7 = reversable defect
#    - target : 0 = less chance of heart attack, 1 = more chance of heart
#                 attack

# %% [markdown]
# ###  Display bottom 5 rows in  the dataset

# %%
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %% [markdown]
# ### Find Shape of our Dataset

# %%
df.shape
print("Number of rows : ",df.shape[0])
print("Number of columns : ",df.shape[1])
# Out:
# Number of rows :  1025
# Number of columns :  14

# %% [markdown]
# ### Get Information about our Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %% [markdown]
# ### Check null values in the Dataset

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# ### Check for Duplicate data and drop them

# %%
data_dup = df.duplicated().any()
data_dup
# Out:
# True

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (302, 14)

# %% [markdown]
# ### Get Overall Statistics about the dataset

# %%
df.describe()
# Out:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# ...

# %% [markdown]
# ### Draw Correlation Matrix

# %%
plt.figure(figsize=[12,6])
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# ### How many people have Heart Disease, and How many don't have heart disease in this Dataset ?

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df['target'].value_counts()
# Out:
# 1    164
# 0    138
# Name: target, dtype: int64

# %%
plt.figure(figsize=[8,5])
sns.countplot(x=df['target'],palette='Set2')
sns.set_theme(style="darkgrid")
plt.xticks([0,1],['People without Heart Disease',
                  'People with Heart Disease'])
plt.xlabel("")
plt.show()

# %% [markdown]
# ### Find count of Male and Female in this Dataset

# %%
df['sex'].value_counts()
# Out:
# 1    206
# 0     96
# Name: sex, dtype: int64

# %%
plt.figure(figsize=[8,5])
colors = ['#FF69B4','#33BCFF']
sns.countplot(x=df['sex'],palette=colors)
plt.xticks([0,1],['Female','Male'])
plt.xlabel('Gender')
plt.title('Count of Male and Female')
plt.show()

# %% [markdown]
# ### Find Gender distribution according to the target variable

# %%
colors = ['#FF69B4','#33BCFF','#E74C3C','#73C6B6']
plt.figure(figsize=[8,5])
sns.countplot(x=df['sex'],hue=df['target'],palette='Set1')
plt.xticks([0,1],['Female','Male'],fontsize=20)
plt.xlabel("")
plt.ylabel("")
plt.legend(labels=['No-Disease','Disease'],fontsize=12)
plt.show()

# %% [markdown]
# ### Age Distribution in the dataset

# %%
sns.histplot(df['age'],bins=20,kde=True) # Kernel Density estimate line
plt.show()

# %% [markdown]
# ### Check Chest pain type

# %% [markdown]
# chest pain type (4 values)
#    - value 0: typical angina
#    - value 1: atypical angina
#    - value 2: non-anginal pain
#    - value 3: asymptomatic

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
plt.figure(figsize=[12,7])
color = ['#3CB371','#FF7F50','#483D8B','#DDA0DD']
sns.countplot(x=df['cp'],palette=color)
plt.xticks([0,1,2,3],['Typical angina','Atypical angina',
                      'Non-anginal pain','Asymptomatic'],fontsize=16)
plt.xlabel("Chest pain types",fontsize=22,fontweight='bold')
plt.ylabel("Count",fontweight='bold',fontsize=20)
plt.show()

# %% [markdown]
# ### The Chest Pain Distribution as per Target variable

# %%
plt.figure(figsize=[10,6])
color = ['#008080','#CD7F32']
sns.countplot(x=df['cp'],hue=df['target'],palette=color)
plt.xticks([0,1,2,3],['Typical angina','Atypical angina',
                      'Non-anginal pain','Asymptomatic'],fontsize=16)
plt.xlabel("Chest pain types",fontsize=22,fontweight='bold')
plt.ylabel("Count",fontweight='bold',fontsize=20)

plt.legend(labels=['No-Disease','Disease'],fontsize=16)
plt.show()

# %% [markdown]
# ### Show Fasting Blood Sugar distribution according to Target variable

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
plt.figure(figsize=[10,6])
colors = ['#DE3163','#FFD700']

sns.countplot(x=df['fbs'],hue=df['target'],palette=colors)
plt.xlabel("Fasting blood sugar",fontsize=20,fontweight='bold')
plt.ylabel("Count",fontweight='bold',fontsize=20)

plt.legend(labels=['No-Disease','Disease'],fontsize=14)
plt.show()

# %% [markdown]
# ### Check Resting Blood Pressure Distribution

# %%
df['trestbps'].hist()
plt.show()

# %% [markdown]
# ### Compare Resting Blood Pressure as per sex column

# %%
g = sns.FacetGrid(df,hue='sex',aspect=3)
g.map(sns.kdeplot,'trestbps',fill=True)
plt.legend(labels=['Male','Female'])
plt.show()

# %% [markdown]
# ### Show Distribution of Serum cholestrol

# %%
df['chol'].hist()
plt.show()

# %% [markdown]
# ### Plot Continuous variables

# %%
cate_val = []
cont_val = []
for column in df.columns:
    if df[column].nunique() <=10:
        cate_val.append(column)
    else:
        cont_val.append(column)

# %%
cate_val
# Out:
# ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'target']

# %%
cont_val
# Out:
# ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# %%
df.hist(cont_val,figsize=[14,10])
plt.tight_layout()
plt.show()
